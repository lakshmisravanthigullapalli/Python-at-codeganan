# %%
# string reading from the user
#input():this function is used to read dynamically from user
               #this fuction by default read it as string data type
s=input()
print(type(s))
print(s)
# Out:
#  sravs
# <class 'str'>
# sravs

# %%
# string operations
#1.string concantenation(using+operator)
#2.string repetetion(using *operation)
s1="code"
s2="gnan"#to give space s1+" "+s2 
s3=s1+s2
print(s3)
# Out:
# codegnan

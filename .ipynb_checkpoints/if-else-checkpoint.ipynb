# %% [markdown]
# ### Conditional statements

# %%
#if else
num=int(input())
if num%3==0:
    print(f"{num} is divisible by 3")
else:
    print(f"{num} is divisible by not 3")
# Out:
#  3
# 3 is divisible by 3

# %%
num=int(input())
if num%3==0 and num%5==0:
     print(f"{num} is divisible by 3 and 5")
else:
    print(f"{num} is not divisible by  3")
# Out:
#  15
# 15 is divisible by 3

# %%
num=int(input())
if num%3==0 or num%5==0:
     print(f"{num} is divisible by 3 and 5")
else:
    print(f"{num} is not divisible  by  3 and 5")
# Out:
#  4
# 4 is not divisible  by  3

# %%
#check even or odd
num=int(input())
if num%2==0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")
# Out:
#  3
# 3 is odd

# %%
#check even or odd
num=int(input())
if num & 1==0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")
# Out:
#  8
# 8 is even

# %%
#check even or odd
num=int(input())
if num % 2:#here if (0) is false and if not equal to 0 that is true. if checks the numbers also 
    print(f"{num} is even")
else:
    print(f"{num} is odd")
# Out:
#  10
# 10 is even

# %%
# generate total bill if total bill morethan 500 then give 10% otherwise )%
total_bill=int(input())
if total_bill>500:
    discount=total_bill*(10/1100)#0r 0.1
    print(f"Total bill after 10% discont:{total_bill-discount}")
else:
    print(f"total bill after 0% discount{total_bill}")
# Out:
#  500
# total bill after 0% discount500

# %%
#check weather  product is available or not not(read name from the user
products=input()
stock=int(input())
if stock>0:
    print(f'currently

# %%
#5th question
#dictionary dont take from the user for the products list
products ={'pen':5,'book':20,"pencil":3}
item=input()
quantity=int(input())
if item in products:
    total_amount=products.get(item)*quantity
    print(f"Total amount of{quantity}{item}:{total_amount}")
else:
    print(f"items not found")
# Out:
#  Pen
#  10
# items not found

# %%
#5th question
#dictionary dont take from the user for the products list
products ={'pen':5,'book':20,"pencil":3}
item=input().lower()
quantity=int(input())
if item in products:
    total_amount=products.get(item)*quantity
    print(f"Total amount of{quantity}{item}:{total_amount}")
else:
    print(f"items not found")
# Out:
#  Pen
#  10
# Total amount of10pen:50

# %%
#check weather the number is positive or negative or zero
num=int(input())
if num>0:
    print(f"{num}is positive")
elif num<0:
     print(f"{num}is negative")
else:
     print(f"{num}is zero")
# Out:
#  0
# 0is zero

# %%
#divisible by 3-fizz
#divisible by5-buzz
#both-fizz buzz
num=int(input())
if num%3==0:
    print(f"{num} is fizz")
elif num%5==0:
    print(f"{num} is buzz") 
elif num%3==0 and num%5==0:
    print("fizz buzz")
else:
    print("invalid")
# Out:
#  15
# 15 is fizz

# %%
#divisible by 3-fizz
#divisible by5-buzz
#both-fizz buzz
num=int(input())#here conditions have prioity
if num%3==0 and num%5==0:
    print("fizz buzz")
elif num%3==0:    
    print(f"{num} is fizz")
elif num%5==0:
    print(f"{num} is buzz") 

else:
    print("invalid")
# Out:
#  15
# fizz buzz

# %%
#largest of two numebers
a=int(input())
b=int(input())
if a>b:
    print(f"{a} is greater")
else:
    print(f"{b} is greater")
# Out:
#  5
#  3
# 5 is greater

# %%
a=int(input())
if a>=18:
    print("this person is eligible to cast vote")
else:
    print("this person is not eligible to cast vote")
# Out:
#  19
# this person is eligible to cast vote

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
    print("a is greater")
elif b<c and b<a:
    print("b is greater")
else:
    print("c is greater")
# Out:
#  45
#  67
#  78
# c is greater

# %%
a=int(input())
if a%2==0 and a>0:
    print("a is positive even")
elif a%2==1 and a>0:
    print("a is positive odd")
elif a<0:
    print("negative")
else:
    print("zero")
# Out:
#  13
# a is positive odd

# %%
a=int(input())
if a%4==0 and a%100==0:
    print("print leap year")
else:
    print("print not leap year")
# Out:
#  2000
# print leap year

# %%
num=int(input())
if num%2==0 and num>0:
    print("positive even number")
elif num%2==1 and num>0:
    print("positive odd number")
elif num%-2==0 and num<0:
    print("negative even number")
elif num%-2==-1 and num<0:
    print("negative odd number")
else:
    print("zero")
# Out:
#  -500
# negative even number

# %%
num=int(input())
if num%2==0 and num>=0:
    print("positive even number")
elif num%2==1 and num>0:
    print("positive odd number")
elif num%2==0 and num<0:
    print("negative even number")
else:
    print("negative odd number")
# Out:
#  -9
# negative odd number

# %%
n=int(input())
#+ve even or not
if n>=0 and n%2==0:
    print("positive even")
elif n>=0:
    print(" positive odd")
elif n %2==0:
    print("negative even")
else:
    print("negativeodd")
# Out:
#  6
# positive even

# %%
#greates t of three numbers
a=int(input())#a,b,c=map(int,input()
b=int(input())
c=int(input())
if a>b and a>c:
    print(f"{a} is greatest")
elif b>c and b>a:
    print(f"{b} is greatest")
else:
    print("c is greatest")
# Out:
#  6
#  5
#  4
# 6 is greatest

# %%
#greates t of three numbers
a,b,c=map(int,input().split())
if a>b and a>c:
    print(f"{a} is greatest")
elif b>c and b>a:
    print(f"{b} is greatest")
else:
    print("c is greatest")
# Out:
#  1 2 3
# c is greatest

# %%
#greates t of three numbers
a=int(input())
b=int(input())
c=int(input())
if a<b and a<c:
    print(f"{a} is smallest")
elif b<c :
    print(f"{b} is smallest")
else:
    print("c is smallest")
# Out:
#  2
#  3
#  4
# 2 is smallest

# %%
n=int(input())
if n>0:
    if n%2==0:
        print("positive even")
    else:
        print("positive odd")
else:
    if n%2==0:
       print("negative even")
    else:
        print("negativ odd")
# Out:
#  -4
# negative even

# %%
a,b,c=map(int,input().split())
if a>b:
    if a>c:
        print("a is greatest")
elif b>c:
    print("b is greatest")
else:
    print ("c is greatest")
# Out:
#  1 2 3
# c is greatest

# %%
a,b,c=map(int,input().split())
if a>b:
    if a>c:
        print("a is greatest")
    else:
        print("b is greatest")
else:
    print ("c is greatest")
# Out:
#  1 2 3
# c is greatest

# %%
a,b,c=map(int,input().split())
if a>b:
    if a>c:
        print("a is greatest")
    else:
        print("c is greatest")
else:
    if b>c:
        print ("b is greatest")
    else:
        print("c is greatest")
# Out:
#  2 3 3
# c is greatest
